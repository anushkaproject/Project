# %%
import warnings
warnings.filterwarnings("ignore")
import numpy as np
import pandas as pd
from pandas import datetime
import matplotlib.pyplot as plt
import seaborn as sns 
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.model_selection import train_test_split

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/train.csv", parse_dates = True ,index_col = 'Date')

store = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/store.csv")
train.index
# Out:
# DatetimeIndex(['2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31', '2015-07-31', '2015-07-31',
#                '2015-07-31', '2015-07-31',
#                ...
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01', '2013-01-01', '2013-01-01',
#                '2013-01-01', '2013-01-01'],
#               dtype='datetime64[ns]', name='Date', length=1017209, freq=None)

# %%
train.shape
# Out:
# (1017209, 8)

# %%
train.head(5)
# Out:
#             Store  DayOfWeek  Sales  ...  Promo  StateHoliday  SchoolHoliday
# Date                                 ...
# 2015-07-31      1          5   5263  ...      1             0              1
# 2015-07-31      2          5   6064  ...      1             0              1
# 2015-07-31      3          5   8314  ...      1             0              1
# 2015-07-31      4          5  13995  ...      1             0              1
# 2015-07-31      5          5   4822  ...      1             0              1
#
# [5 rows x 8 columns]

# %%
train['Year'] = train.index.year
train['Month'] = train.index.month
train['Day'] = train.index.day
train['WeekOfYear'] = train.index.weekofyear

train['SalePerCustomer'] = train['Sales']/train['Customers']
train['SalePerCustomer'].describe()
# Out:
# count    844340.000000
# mean          9.493619
# std           2.197494
# min           0.000000
# 25%           7.895563
# 50%           9.250000
# 75%          10.899729
# max          64.957854
# Name: SalePerCustomer, dtype: float64

# %%
zero_sales = train[(train.Open != 0) & (train.Sales == 0)]
print("In total: ", zero_sales.shape)
zero_sales.head(5)
# Out:
# In total:  (54, 13)
#             Store  DayOfWeek  Sales  ...  Day  WeekOfYear  SalePerCustomer
# Date                                 ...
# 2015-05-15    971          5      0  ...   15          20              NaN
# 2015-03-26    674          4      0  ...   26          13              NaN
# 2015-02-05    699          4      0  ...    5           6              NaN
# 2014-10-01    708          3      0  ...    1          40              NaN
# 2014-09-22    357          1      0  ...   22          39              NaN
#
# [5 rows x 13 columns]

# %%
train = train[(train["Open"] != 0) & (train['Sales'] != 0)]

print("In total: ", train.shape)
# Out:
# In total:  (844338, 13)

# %%
store.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store['CompetitionDistance'].fillna(store['CompetitionDistance'].median(), inplace = True)

# %%
store.fillna(0, inplace = True)

# %%
print("Joining train set with an additional store information.")
train_store = pd.merge(train, store, how = 'inner', on = 'Store')
print("In total: ", train_store.shape)
train_store.head()
# Out:
# Joining train set with an additional store information.
# In total:  (844338, 22)
#    Store  DayOfWeek  Sales  ...  Promo2SinceWeek  Promo2SinceYear  PromoInterval
# 0      1          5   5263  ...              0.0              0.0              0
# 1      1          4   5020  ...              0.0              0.0              0
# 2      1          3   4782  ...              0.0              0.0              0
# 3      1          2   5011  ...              0.0              0.0              0
# 4      1          1   6102  ...              0.0              0.0              0
#
# [5 rows x 22 columns]

# %%
sns.factorplot(data = train_store, x = 'Month', y = "Sales", 
               col = 'StoreType', 
               palette = 'plasma',
               hue = 'StoreType',
               row = 'Promo')

# %%
corr_all = train_store.drop('Open', axis = 1).corr()

mask = np.zeros_like(corr_all, dtype = np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize = (11, 9))

sns.heatmap(corr_all, mask = mask,
            square = True, linewidths = .5, ax = ax, cmap = "BuPu")      
plt.show()

# %%
store = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/store.csv")
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/train.csv",parse_dates=[2])
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/test.csv",parse_dates=[3])

# %%
store.head()
# Out:
#    Store StoreType  ... Promo2SinceYear    PromoInterval
# 0      1         c  ...             NaN              NaN
# 1      2         a  ...          2010.0  Jan,Apr,Jul,Oct
# 2      3         a  ...          2011.0  Jan,Apr,Jul,Oct
# 3      4         c  ...             NaN              NaN
# 4      5         a  ...             NaN              NaN
#
# [5 rows x 10 columns]

# %%
store.isnull().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %%
store.PromoInterval.value_counts()
# Out:
# Jan,Apr,Jul,Oct     335
# Feb,May,Aug,Nov     130
# Mar,Jun,Sept,Dec    106
# Name: PromoInterval, dtype: int64

# %%
store.fillna(0, inplace=True)

# %%
train.head().append(train.tail())
# Out:
#          Store  DayOfWeek       Date  ...  Promo  StateHoliday  SchoolHoliday
# 0            1          5 2015-07-31  ...      1             0              1
# 1            2          5 2015-07-31  ...      1             0              1
# 2            3          5 2015-07-31  ...      1             0              1
# 3            4          5 2015-07-31  ...      1             0              1
# 4            5          5 2015-07-31  ...      1             0              1
# 1017204   1111          2 2013-01-01  ...      0             a              1
# 1017205   1112          2 2013-01-01  ...      0             a              1
# 1017206   1113          2 2013-01-01  ...      0             a              1
# 1017207   1114          2 2013-01-01  ...      0             a              1
# 1017208   1115          2 2013-01-01  ...      0             a              1
#
# [10 rows x 9 columns]

# %%
train.isnull().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
train.Open.value_counts()
# Out:
# 1    844392
# 0    172817
# Name: Open, dtype: int64

# %%
np.sum([train['Sales'] == 0])
# Out:
# 172871

# %%
store_1 = train.loc[(train["Store"]==1)&(train['Sales']>0), ['Date',"Sales"]]
store_10 = train.loc[(train["Store"]==10)&(train['Sales']>0), ['Date',"Sales"]]
f = plt.figure(figsize=(18,10))
ax1 = f.add_subplot(211)
ax1.plot(store_1['Date'], store_1['Sales'], '-')
ax1.set_xlabel('Time')
ax1.set_ylabel('Sales')
ax1.set_title('Store 1 Sales Distribution')

ax2 = f.add_subplot(212)
ax2.plot(store_10['Date'], store_10['Sales'], '-')
ax2.set_xlabel('Time')
ax2.set_ylabel('Sales')
ax2.set_title('Store 10 Sales Distribution')
# Out:
# Text(0.5, 1.0, 'Store 10 Sales Distribution')

# %%
test.head()
# Out:
#    Id  Store  DayOfWeek       Date  Open  Promo StateHoliday  SchoolHoliday
# 0   1      1          4 2015-09-17   1.0      1            0              0
# 1   2      3          4 2015-09-17   1.0      1            0              0
# 2   3      7          4 2015-09-17   1.0      1            0              0
# 3   4      8          4 2015-09-17   1.0      1            0              0
# 4   5      9          4 2015-09-17   1.0      1            0              0

# %%
test.isnull().sum()
# Out:
# Id                0
# Store             0
# DayOfWeek         0
# Date              0
# Open             11
# Promo             0
# StateHoliday      0
# SchoolHoliday     0
# dtype: int64

# %%
sns.countplot(x = 'DayOfWeek', hue = 'Open', data = test)
plt.title('Store Daily Open Countplot')
# Out:
# Text(0.5, 1.0, 'Store Daily Open Countplot')

# %%
test[test.Open.isnull()]
# Out:
#           Id  Store  DayOfWeek  ... Promo  StateHoliday  SchoolHoliday
# 479      480    622          4  ...     1             0              0
# 1335    1336    622          3  ...     1             0              0
# 2191    2192    622          2  ...     1             0              0
# 3047    3048    622          1  ...     1             0              0
# 4759    4760    622          6  ...     0             0              0
# 5615    5616    622          5  ...     0             0              0
# 6471    6472    622          4  ...     0             0              0
# 7327    7328    622          3  ...     0             0              0
# 8183    8184    622          2  ...     0             0              0
# 9039    9040    622          1  ...     0             0              0
# 10751  10752    622          6  ...     0             0              0
#
# [11 rows x 8 columns]

# %%
test.fillna(value = 1, inplace = True)

# %%
train = pd.merge(train, store, on='Store')
test = pd.merge(test, store, on='Store')

# %%
train = train.sort_values(['Date'],ascending = False)
train_total = train.copy()

split_index = 6*7*1115
valid = train[:split_index] 
train = train[split_index:]

valid = valid[(valid.Open != 0)&(valid.Sales >0)]
train = train[(train.Open != 0)&(train.Sales >0)]
train_total = train_total[(train_total.Open != 0)&(train_total.Sales >0)]

# %%
fig = plt.figure(figsize=(12,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
g1 = sns.distplot(train['Sales'],hist = True,label='skewness:{:.2f}'.format(train['Sales'].skew()),ax = ax1)
g1.legend()
g1.set(xlabel = 'Sales', ylabel = 'Density', title = 'Sales Distribution')
g2 = sns.distplot(np.log1p(train['Sales']),hist = True,label='skewness:{:.2f}'.format(np.log1p(train['Sales']).skew()),ax=ax2)
g2.legend()
g2.set(xlabel = 'log(Sales+1)',ylabel = 'Density', title = 'log(Sales+1) Distribution')
plt.show()

# %%
def process(data, isTest = False):
    mappings = {'0':0, 'a':1, 'b':2, 'c':3, 'd':4}
    data.StoreType.replace(mappings, inplace=True)
    data.Assortment.replace(mappings, inplace=True)
    data.StateHoliday.replace(mappings, inplace=True)
    
    data['Month'] = data.Date.dt.month
    data['Year'] = data.Date.dt.year
    data['Day'] = data.Date.dt.day
    data['WeekOfYear'] = data.Date.dt.weekofyear
    
    data['CompetitionOpen'] = 12 * (data.Year - data.CompetitionOpenSinceYear) + \
        (data.Month - data.CompetitionOpenSinceMonth)
    data['CompetitionOpen'] = data['CompetitionOpen'].apply(lambda x: x if x > 0 else 0)
    
    data['PromoOpen'] = 12 * (data.Year - data.Promo2SinceYear) + \
        (data.WeekOfYear - data.Promo2SinceWeek) / 4.0
    data['PromoOpen'] = data['PromoOpen'].apply(lambda x: x if x > 0 else 0)
                                                 
    month2str = {1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May', 6:'Jun', \
             7:'Jul', 8:'Aug', 9:'Sept', 10:'Oct', 11:'Nov', 12:'Dec'}
    data['month_str'] = data.Month.map(month2str)

    def check(row):
        if isinstance(row['PromoInterval'],str) and row['month_str'] in row['PromoInterval']:
            return 1
        else:
            return 0
        
    data['IsPromoMonth'] =  data.apply(lambda row: check(row),axis=1)    
    
    features = ['Store', 'DayOfWeek', 'Promo', 'StateHoliday', 'SchoolHoliday',
       'StoreType', 'Assortment', 'CompetitionDistance',
       'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo2',
       'Promo2SinceWeek', 'Promo2SinceYear', 'Year', 'Month', 'Day',
       'WeekOfYear', 'CompetitionOpen', 'PromoOpen', 'IsPromoMonth']  
    if not isTest:
        features.append('Sales')
        
    data = data[features]
    return data

train = process(train)
valid = process(valid)
train_total = process(train_total)
x_test = process(test,isTest = True)

# %%
valid.sort_index(inplace = True)
train.sort_index(inplace = True)
train_total.sort_index(inplace = True)

x_train, y_train = train.drop(columns = ['Sales']), np.log1p(train['Sales'])
x_valid, y_valid = valid.drop(columns = ['Sales']), np.log1p(valid['Sales'])
x_train_total, y_train_total = train_total.drop(columns = ['Sales']), np.log1p(train_total['Sales'])

# %%
def rmspe(y, yhat):
    return np.sqrt(np.mean((yhat/y-1) ** 2))

def rmspe_xg(yhat, y):
    y = np.expm1(y.get_label())
    yhat = np.expm1(yhat)
    return "rmspe", rmspe(y,yhat)

# %%
clf = RandomForestRegressor(n_estimators = 15)
clf.fit(x_train, y_train)
y_pred = clf.predict(x_valid)
error = rmspe(np.expm1(y_valid), np.expm1(y_pred))
print('RMSPE: {:.4f}'.format(error))
# Out:
# RMSPE: 0.1588

# %%
feat_importances = pd.Series(clf.feature_importances_, index=x_train.columns)
feat_importances.nlargest(10).sort_values(ascending = True).plot(kind='barh')
plt.xlabel('importance')
plt.title('Feature Importance')
# Out:
# Text(0.5, 1.0, 'Feature Importance')

# %%
def build_features(features, data):
    data.fillna(0, inplace=True)
    data.loc[data.Open.isnull(), 'Open'] = 1
    features.extend(['Store', 'CompetitionDistance', 'CompetitionOpenSinceMonth',
                     'CompetitionOpenSinceYear', 'Promo', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear'])

    features.append('SchoolHoliday')
    data['SchoolHoliday'] = data['SchoolHoliday'].astype(float)
    features.append('DayOfWeek')
    features.append('month')
    features.append('day')
    features.append('year')
    data['year'] = data.Date.apply(lambda x: x.split('-')[0])
    data['year'] = data['year'].astype(float)
    data['month'] = data.Date.apply(lambda x: x.split('-')[1])
    data['month'] = data['month'].astype(float)
    data['day'] = data.Date.apply(lambda x: x.split('-')[2])
    data['day'] = data['day'].astype(float)

    features.append('StoreType')
    data.loc[data['StoreType'] == 'a', 'StoreType'] = '1'
    data.loc[data['StoreType'] == 'b', 'StoreType'] = '2'
    data.loc[data['StoreType'] == 'c', 'StoreType'] = '3'
    data.loc[data['StoreType'] == 'd', 'StoreType'] = '4'
    data['StoreType'] = data['StoreType'].astype(float)

    features.append('Assortment')
    data.loc[data['Assortment'] == 'a', 'Assortment'] = '1'
    data.loc[data['Assortment'] == 'b', 'Assortment'] = '2'
    data.loc[data['Assortment'] == 'c', 'Assortment'] = '3'
    data['Assortment'] = data['Assortment'].astype(float)

# %%
train = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/train.csv")
test = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/test.csv")
store = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/New_task/store.csv")

print("Assume store open, if not provided")
test.fillna(1, inplace=True)

print("Consider only open stores for training. Closed stores wont count into the score.")
train = train[train["Open"] != 0]

print("Join with store")
train = pd.merge(train, store, on='Store')
test = pd.merge(test, store, on='Store')

features = []

print("augment features")
build_features(features, train)
build_features([], test)
print(features)

params = {"objective": "reg:linear",
          "eta": 0.3,
          "max_depth": 8,
          "subsample": 0.7,
          "colsample_bytree": 0.7,
          "silent": 1
          }
num_trees = 300

print("Train a XGBoost model")
val_size = 100000
print(train.tail(1)['Date'])
X_train, X_test = train_test_split(train, test_size=0.01)
dtrain = xgb.DMatrix(X_train[features], np.log(X_train["Sales"] + 1))
dvalid = xgb.DMatrix(X_test[features], np.log(X_test["Sales"] + 1))
dtest = xgb.DMatrix(test[features])
watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=50, feval=rmspe_xg, verbose_eval=True)
# Out:
# Assume store open, if not provided
# Consider only open stores for training. Closed stores wont count into the score.
# Join with store
# augment features
# ['Store', 'CompetitionDistance', 'CompetitionOpenSinceMonth', 'CompetitionOpenSinceYear', 'Promo', 'Promo2', 'Promo2SinceWeek', 'Promo2SinceYear', 'SchoolHoliday', 'DayOfWeek', 'month', 'day', 'year', 'StoreType', 'Assortment']
# Train a XGBoost model
# 844391    2013-01-02
# Name: Date, dtype: object
# [0]	eval-rmse:5.7944	train-rmse:5.79371	eval-rmspe:inf	train-rmspe:inf
# Multiple eval metrics have been passed: 'train-rmspe' will be used for early stopping.
#
# Will train until train-rmspe hasn't improved in 50 rounds.
# [1]	eval-rmse:4.06423	train-rmse:4.06383	eval-rmspe:inf	train-rmspe:inf
# [2]	eval-rmse:2.85514	train-rmse:2.85469	eval-rmspe:inf	train-rmspe:inf
# [3]	eval-rmse:2.01283	train-rmse:2.01203	eval-rmspe:inf	train-rmspe:inf
# [4]	eval-rmse:1.42768	train-rmse:1.42562	eval-rmspe:inf	train-rmspe:inf
# [5]	eval-rmse:1.02594	train-rmse:1.02255	eval-rmspe:inf	train-rmspe:inf
# [6]	eval-rmse:0.753687	train-rmse:0.748108	eval-rmspe:inf	train-rmspe:inf
# [7]	eval-rmse:0.571013	train-rmse:0.562832	eval-rmspe:inf	train-rmspe:inf
# [8]	eval-rmse:0.45807	train-rmse:0.447045	eval-rmspe:inf	train-rmspe:inf
# [9]	eval-rmse:0.386728	train-rmse:0.372676	eval-rmspe:inf	train-rmspe:inf
# [10]	eval-rmse:0.347765	train-rmse:0.331199	eval-rmspe:inf	train-rmspe:inf
# [11]	eval-rmse:0.326331	train-rmse:0.307846	eval-rmspe:inf	train-rmspe:inf
# [12]	eval-rmse:0.309907	train-rmse:0.289862	eval-rmspe:inf	train-rmspe:inf
# [13]	eval-rmse:0.294756	train-rmse:0.273789	eval-rmspe:inf	train-rmspe:inf
# [14]	eval-rmse:0.28917	train-rmse:0.267488	eval-rmspe:inf	train-rmspe:inf
# [15]	eval-rmse:0.286848	train-rmse:0.264455	eval-rmspe:inf	train-rmspe:inf
# [16]	eval-rmse:0.280814	train-rmse:0.257625	eval-rmspe:inf	train-rmspe:inf
# [17]	eval-rmse:0.275225	train-rmse:0.251146	eval-rmspe:inf	train-rmspe:inf
# [18]	eval-rmse:0.271754	train-rmse:0.24717	eval-rmspe:inf	train-rmspe:inf
# [19]	eval-rmse:0.264176	train-rmse:0.238399	eval-rmspe:inf	train-rmspe:inf
# [20]	eval-rmse:0.263489	train-rmse:0.23764	eval-rmspe:inf	train-rmspe:inf
# [21]	eval-rmse:0.261743	train-rmse:0.235796	eval-rmspe:inf	train-rmspe:inf
# [22]	eval-rmse:0.258727	train-rmse:0.232112	eval-rmspe:inf	train-rmspe:inf
# [23]	eval-rmse:0.255194	train-rmse:0.228261	eval-rmspe:inf	train-rmspe:inf
# [24]	eval-rmse:0.252598	train-rmse:0.225312	eval-rmspe:inf	train-rmspe:inf
# [25]	eval-rmse:0.251239	train-rmse:0.223871	eval-rmspe:inf	train-rmspe:inf
# [26]	eval-rmse:0.249306	train-rmse:0.221948	eval-rmspe:inf	train-rmspe:inf
# [27]	eval-rmse:0.248498	train-rmse:0.220949	eval-rmspe:inf	train-rmspe:inf
# [28]	eval-rmse:0.245065	train-rmse:0.217415	eval-rmspe:inf	train-rmspe:inf
# [29]	eval-rmse:0.242885	train-rmse:0.21476	eval-rmspe:inf	train-rmspe:inf
# [30]	eval-rmse:0.242317	train-rmse:0.213901	eval-rmspe:inf	train-rmspe:inf
# [31]	eval-rmse:0.237551	train-rmse:0.208003	eval-rmspe:inf	train-rmspe:inf
# [32]	eval-rmse:0.235463	train-rmse:0.2054	eval-rmspe:inf	train-rmspe:inf
# [33]	eval-rmse:0.228822	train-rmse:0.197753	eval-rmspe:inf	train-rmspe:inf
# [34]	eval-rmse:0.227807	train-rmse:0.19658	eval-rmspe:inf	train-rmspe:inf
# [35]	eval-rmse:0.224682	train-rmse:0.193033	eval-rmspe:inf	train-rmspe:inf
# [36]	eval-rmse:0.220921	train-rmse:0.188499	eval-rmspe:inf	train-rmspe:inf
# [37]	eval-rmse:0.220289	train-rmse:0.187783	eval-rmspe:inf	train-rmspe:inf
# [38]	eval-rmse:0.219663	train-rmse:0.18695	eval-rmspe:inf	train-rmspe:inf
# [39]	eval-rmse:0.218857	train-rmse:0.186094	eval-rmspe:inf	train-rmspe:inf
# [40]	eval-rmse:0.218066	train-rmse:0.184924	eval-rmspe:inf	train-rmspe:inf
# [41]	eval-rmse:0.217061	train-rmse:0.183764	eval-rmspe:inf	train-rmspe:inf
# [42]	eval-rmse:0.214808	train-rmse:0.180757	eval-rmspe:inf	train-rmspe:inf
# [43]	eval-rmse:0.213513	train-rmse:0.17941	eval-rmspe:inf	train-rmspe:inf
# [44]	eval-rmse:0.211904	train-rmse:0.177288	eval-rmspe:inf	train-rmspe:inf
# [45]	eval-rmse:0.210835	train-rmse:0.176073	eval-rmspe:inf	train-rmspe:inf
# [46]	eval-rmse:0.209005	train-rmse:0.173541	eval-rmspe:inf	train-rmspe:inf
# [47]	eval-rmse:0.207794	train-rmse:0.171728	eval-rmspe:inf	train-rmspe:inf
# [48]	eval-rmse:0.207335	train-rmse:0.170999	eval-rmspe:inf	train-rmspe:inf
# [49]	eval-rmse:0.206229	train-rmse:0.169559	eval-rmspe:inf	train-rmspe:inf
# [50]	eval-rmse:0.204848	train-rmse:0.16784	eval-rmspe:inf	train-rmspe:inf
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-74-bfc45106d7da> in <module>()
#      37 dtest = xgb.DMatrix(test[features])
#      38 watchlist = [(dvalid, 'eval'), (dtrain, 'train')]
# ---> 39 gbm = xgb.train(params, dtrain, num_trees, evals=watchlist, early_stopping_rounds=50, feval=rmspe_xg, verbose_eval=True)
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, learning_rates)
#     214                            evals=evals,
#     215                            obj=obj, feval=feval,
# --> 216                            xgb_model=xgb_model, callbacks=callbacks)
#     217
#     218
#
# /usr/local/lib/python3.7/dist-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks)
#      97                                end_iteration=num_boost_round,
#      98                                rank=rank,
# ---> 99                                evaluation_result_list=evaluation_result_list))
#     100         except EarlyStopException:
#     101             break
#
# /usr/local/lib/python3.7/dist-packages/xgboost/callback.py in callback(env)
#     243                                    best_msg=state['best_msg'])
#     244         elif env.iteration - best_iteration >= stopping_rounds:
# --> 245             best_msg = state['best_msg']
#     246             if verbose and env.rank == 0:
#     247                 msg = "Stopping. Best iteration:\n{}\n\n"
#
# KeyError: 'best_msg'
